# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\kowsar\PycharmProjects\PycharmProjects\pythonProject\venv\Scripts\suicide.csv')

# %%
h=data.head()
h
# Out:
#    Country  Year  Suicides number  Life expectancy  Adult Mortality  \
# 0  Albania  2000               54             72.6               11
# 1  Albania  2001              119             73.6               14
# 2  Albania  2002              133             73.3               15
# 3  Albania  2003              124             72.8               18
# 4  Albania  2004              146             73.0               17
#
#    Infant deaths  Alcohol  Under-five deaths  HIV/AIDS          GDP  \
# 0              1     3.66                  1       0.1  1175.788981
# 1              1     4.25                  1       0.1  1326.973390
# 2              1     3.73                  1       0.1  1453.642777
# 3              1     4.29                  1       0.1   189.681557
# 4              1     4.54                  1       0.1  2416.588235
#
#    Population  Income composition of resources  Schooling
# 0     38927.0                            0.656       10.7
# ...

# %%
d=data.describe()
d
# Out:
#               Year  Suicides number  Life expectancy  Adult Mortality  \
# count  1421.000000      1421.000000      1421.000000      1421.000000
# mean   2007.251935      2629.177340        75.233638       116.912738
# std       4.503817      6755.607644         5.399686        74.413799
# min    2000.000000         0.000000        53.700000         1.000000
# 25%    2003.000000        85.000000        72.500000        68.000000
# 50%    2007.000000       501.000000        74.900000       117.000000
# 75%    2011.000000      1867.000000        78.900000       163.000000
# max    2015.000000     56958.000000        89.000000       498.000000
#
#        Infant deaths      Alcohol  Under-five deaths     HIV/AIDS  \
# count    1421.000000  1421.000000        1421.000000  1421.000000
# mean        5.805067     6.664729           7.038705     0.397537
# std        13.088297     3.917763          16.104082     2.227681
# min         0.000000     0.010000           0.000000     0.100000
# ...

# %%
df=pd.DataFrame(data, columns=['Population', 'Suicides number', 'Adult Mortality', 'Infant deaths'])
df
# Out:
#       Population  Suicides number  Adult Mortality  Infant deaths
# 0        38927.0               54               11              1
# 1        36173.0              119               14              1
# 2         3511.0              133               15              1
# 3       339616.0              124               18              1
# 4       326939.0              146               17              1
# ...          ...              ...              ...            ...
# 1416  25646139.0              751              166              9
# 1417  26078766.0              775              158              9
# 1418  26503892.0              760              158              9
# 1419  26926228.0              731              161              9
# 1420  27345912.0              618              159              9
#
# [1421 rows x 4 columns]

# %%
hist=df.hist()

# %%
scatter = plt.scatter(df['Suicides number'], df['Population'], color='blue')
plt.xlabel('Suicides number')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
scatter = plt.scatter(df['Adult Mortality'], df['Population'], color='blue')
plt.xlabel('Adult Mortality')
plt.ylabel('Population')

# %%
scatter = plt.scatter(df['Infant deaths'], df['Population'], color='blue')
plt.xlabel('Infant deaths')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
msk=np.random.rand(len(df))< 0.8
train=df[msk]
test=df[~msk]
print(msk)
print(train)
print(test)
# Out:
# [ True  True  True ...  True  True False]
#       Population  Suicides number  Adult Mortality  Infant deaths
# 0        38927.0               54               11              1
# 1        36173.0              119               14              1
# 2         3511.0              133               15              1
# 3       339616.0              124               18              1
# 4       326939.0              146               17              1
# ...          ...              ...              ...            ...
# 1415  25209506.0              870              168              9
# 1416  25646139.0              751              166              9
# 1417  26078766.0              775              158              9
# 1418  26503892.0              760              158              9
# 1419  26926228.0              731              161              9
#
# [1121 rows x 4 columns]
#       Population  Suicides number  Adult Mortality  Infant deaths
# ...

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.scatter(train['Suicides number'],train['Population'], color='blue')
ax1.scatter(test['Suicides number'], test['Population'], color='red')
plt.xlabel('Suicides number')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.scatter(train['Adult Mortality'],train['Population'], color='blue')
ax1.scatter(test['Adult Mortality'], test['Population'], color='red')
plt.xlabel('Adult Mortality')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.scatter(train['Infant deaths'],train['Population'], color='blue')
ax1.scatter(test['Infant deaths'], test['Population'], color='red')
plt.xlabel('Infant deaths')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
train_x=np.asanyarray(train[['Suicides number','Adult Mortality','Infant deaths']])
train_y=np.asanyarray(train[['Population']])
reg.fit(train_x, train_y)
coefficent=reg.coef_
intercept=reg.intercept_
print('coefficent', coefficent)
print('intercept',intercept)
# Out:
# coefficent [[   2820.46723683  -65606.94389615 1088363.68574597]]
# intercept [6823182.78567697]

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
train_x=np.asanyarray(train[['Suicides number']])
train_y=np.asanyarray(train[['Population']])
reg.fit(train_x, train_y)
coefficent=reg.coef_
intercept=reg.intercept_
print('coefficent', coefficent)
print('intercept',intercept)
# Out:
# coefficent [[3245.9596711]]
# intercept [4415469.95649294]

# %%
plt.scatter(train['Suicides number'], train['Population'], color='blue')
plt.plot(train_x, reg.coef_[0][0]*train_x + reg.intercept_[0], '-r')

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
train_x=np.asanyarray(train[['Adult Mortality']])
train_y=np.asanyarray(train[['Population']])
reg.fit(train_x, train_y)
coefficent=reg.coef_
intercept=reg.intercept_
print('coefficent', coefficent)
print('intercept',intercept)
# Out:
# coefficent [[-1418.88306292]]
# intercept [13490182.30038646]

# %%
plt.scatter(train[, 'Suicides number''Adult Mortality'], train['Population'], color='blue')
plt.plot(train_x, reg.coef_[0][0]*train_x + reg.intercept_[0], '-r')

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
train_x=np.asanyarray(train[['Suicides number','Adult Mortality','Infant deaths']])
train_y=np.asanyarray(train[['Population']])
reg.fit(train_x, train_y)
coefficent=reg.coef_
intercept=reg.intercept_
print('coefficent', coefficent)
print('intercept',intercept)
# Out:
# coefficent [[   2820.46723683  -65606.94389615 1088363.68574597]]
# intercept [6823182.78567697]

# %%
plt.scatter(train['Infant deaths'], train['Population'], color='blue')
plt.plot(train_x, reg.coef_[0][0]*train_x + reg.intercept_[0], '-r')

# %%
from sklearn.metrics import r2_score
y_hat=reg.predict(np.asanyarray(test[['Suicides number', 'Adult Mortality', 'Infant deaths']]))
xo=np.asanyarray(test[['Suicides number', 'Adult Mortality', 'Infant deaths']])
y=np.asanyarray(test[['Population']])
MSE=np.mean((y_hat - y)**2)
print('MSE',MSE)
print('variance score',reg.score(xo,y))
# Out:
# MSE 627325216398786.2
# variance score 0.3868290767706948

# %%
test
# Out:
#       Population  Suicides number  Adult Mortality  Infant deaths
# 16       80809.0                0              147              0
# 18       83131.0                1              144              0
# 20       85405.0                0               14              0
# 21       88703.0                0              134              0
# 24       91889.0                1               13              0
# ...          ...              ...              ...            ...
# 1400     26167.0             1221              192             24
# 1404    297745.0             1835              184             18
# 1410  23003836.0             1150              172             10
# 1414  24770950.0              897              165              9
# 1420  27345912.0              618              159              9
#
# [300 rows x 4 columns]
